# %%
import pandas as pd
import matplotlib as mplstyle
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
campuscrime = pd.read_csv("campus_crime.csv")

# %%
plt.scatter(x=campuscrime["robbery"],
               y=campuscrime["burglary"],
               s=campuscrime["total_enr"]/1000,
               alpha=0.4)

# %% [markdown]
# Story Idea 1: The general trend seems to be that schools tend to have more burglaries than robberies, which makes since robberies involve the victim being present and using force. So why does the Instituto de Banca Y Comercio Inc have significantly more robberies than burglaries? (It's the outlier toward the right.) No other school has that disproportionate lean toward robberies.

# %%
plt.scatter(x=campuscrime["total_enr"],
               y=campuscrime["burglary"],
               alpha=0.4)

# %%
grid_columns = ["total_enr", "burglary","forcible","vehicle"]
g = sns.PairGrid(campuscrime[grid_columns])
g.map_offdiag(plt.scatter)

# %% [markdown]
# Story Idea 2: The logic should go that the higher the enrollment, the more crimes one can expect. But when comparing enrollment numbers with the most common crimes (per data), there doesn't seem to be that big of a spike. If anything, bigger campuses seemed to have relatively fewer forcible sexual assaults and burglaries. Why is this -- underreporting or something else?

# %%
grid_columns = ["agg_aslt", "burglary"]
g = sns.PairGrid(campuscrime[grid_columns])
g.map_offdiag(plt.scatter)

# %%
gr = sns.lmplot(data=campuscrime, x="burglary", y="agg_aslt")

# %% [markdown]
# Story Idea 3: Seems like the more burglaries, the more aggravated assaults reported. Does the fact more people attempt burglaries mean the chances of assault (due to say coming into contact with whoever is robbed by accident) mean something? Does one type of crime engender other types of crime?
